# %%
import pandas as pd
import numpy as np
import nltk

# %%
df = pd.read_csv("dataframe_containing_job_descriptions.csv",index_col='Unnamed: 0')
df.head()
# Out:
#                  Main Job Title     Searched Job Title  \
# 0         Application Developer  Application Developer
# 1         Application Developer  Application Developer
# 2  Senior Application Developer  Application Developer
# 3  Senior Application Developer  Application Developer
# 4     Web Application Developer  Application Developer
#
#                                Company Name  \
# 0                    IBM India Pvt. Limited
# 1                    IBM India Pvt. Limited
# 2  SHURE AUDIO TECHNOLOGIES PRIVATE LIMITED
# 3                                   ARETHOS
# 4             GENPACT India Private Limited
#
#                                               skills  \
# 0  IT-Skills Java CSS Javascript SAP Blackberry A...
# 1  Performance-tuning GIT Integration-testing Agi...
# 2  Angularjs Web-Technologies Javascript Bootstra...
# 3  .Net-Core Microsoft-Azure ASP.Net-MVC program-...
# 4  C# CSS LINQ Telerik-Controls ASP.Net-Ajax Java...
#
#                                          description                location  \
# 0                                               None     Bengaluru/Bangalore
# 1                                               None     Bangalore/Bengaluru
# 2  OverviewResponsible for providing technical ex...  Hyderabad/Secunderabad
# 3  Roles and ResponsibilitiesDesign, code, test, ...   Singapore, Chandigarh
# 4                                               None     Bangalore/Bengaluru
#
#                               responsibilty/activity  \
# 0                                               None
# 1                                               None
# 2  responsible for integrating our Enterprise App...
# 3                                               None
# 4                                               None
#
#                                            education Experience  \
# 0                                               None    6-8 Yrs
# 1                                               None    2-5 Yrs
# 2  Education\nUG :B.Sc in Computers, B.Tech/B.E. ...    5-8 Yrs
# 3  Education\nUG :BCA in Any Specialization, B.Sc...    4-9 Yrs
# 4                                               None    3-6 Yrs
#
#   Certifications                    salary  \
# 0                            Not disclosed
# 1                            Not disclosed
# 2                            Not disclosed
# 3                 5,00,000 - 12,00,000 PA.
# 4                            Not disclosed
#
#                                                links  name   exp   job
# 0  https://www.naukri.com/job-listings-applicatio...  None  None  None
# 1  https://www.naukri.com/job-listings-applicatio...  None  None  None
# 2  https://www.naukri.com/job-listings-senior-app...  None  None  None
# 3  https://www.naukri.com/job-listings-senior-app...  None  None  None
# 4  https://www.naukri.com/job-listings-net-web-ap...  None  None  None

# %%
jobs = pd.read_excel("/Work/files/Semantic Titles.xlsx",sheet_name='Sheet1')
jobs.head(2)
# Out:
#                Job Title         Semantic Words                             C  \
# 0  Application Developer  Application Developer  Senior Application Developer
# 1   Application Engineer   Application Engineer   Senior Application Engineer
#
#                             D                             E  \
# 0   Web Application Developer  Mobile Application Developer
# 1  Field Application Engineer  Application Support Engineer
#
#                             F  \
# 0  Lead Application Developer
# 1  Sales Application Engineer
#
#                                                    G  \
# 0  Sap Advanced Business Application Programming ...
# 1                        Application System Engineer
#
#                                                    H  \
# 0                   Senior Web Application Developer
# 1  Application Specific Integrated Circuit Design...
#
#                                                   I  \
# 0           Advanced Business Application Developer
# 1  Application Specific Integrated Circuit Engineer
#
#                               J  ...                              Q  \
# 0  System Application Developer  ...  Application Support Developer
# 1  Product Application Engineer  ...      Lead Application Engineer
#
#                               R                                S  \
# 0  Junior Application Developer  Principal Application Developer
# 1  Project Application Engineer  Application Engineering Manager
#
#                                                    T  \
# 0  Senior Advanced Business Application Programmi...
# 1                       Service Application Engineer
#
#                                 U  \
# 0  Internet Application Developer
# 1        Web Application Engineer
#
#                                                    V  \
# 0                Senior Oracle Application Developer
# 1  Senior Application Specific Integrated Circuit...
#
#                                                    W  \
# 0  Senior Sap Advanced Business Application Progr...
# 1                Senior Application Support Engineer
#
#                                 X  \
# 0  Application Developer Contract
# 1      Staff Application Engineer
#
#                                                    Y  \
# 0                      Network Application Developer
# 1  Senior Application Specific Integrated Circuit...
#
#                                Z
# 0                            NaN
# 1  Customer Application Engineer
#
# [2 rows x 26 columns]

# %% [markdown]
# ## MAIN FUNCTION

# %%
def skillarray(X,job):
    x = X[X['Searched Job Title']==job]
    if(len(x)==0):
        return np.array(['None','None','None','None','None'])
    alllist = []
    findict = {}
    for i in x['skills']:
        for j in i.split():
            try:
                findict[j.lower()]+=1
            except:
                findict[j.lower()] = 0
            alllist.append(j.lower())
    alllist = list(np.unique(np.array(alllist)))
    skillset = pd.DataFrame([findict]).transpose()
    skillset.reset_index(inplace=True)
    skillset.columns = ['skills','counts']
    skillset.sort_values('counts',ascending=False,inplace=True)
    skillset['percentage'] = (skillset['counts']/len(x))*100
    skillset['percentage'] = skillset['percentage'].astype(int)
    skillset['fin'] = skillset['skills']+" ("+skillset['percentage'].astype(str)+"%)"
    return np.array(skillset['fin'][0:5])

# %% [markdown]
# ## MAKING THE DATAFRAME

# %%
skilldict = {}
for i in jobs['Job Title']:
    skilldict[i] = skillarray(df,i)

# %% [markdown]
# ## final dataframe

# %%
pd.DataFrame(skilldict).transpose()
# Out:
#                                                    0  \
# Application Developer                it-skills (27%)
# Application Engineer                     linux (12%)
# Application Sales Specialist             sales (40%)
# Area Manager                             sales (14%)
# Area Sales Manager                  area-sales (33%)
# ...                                              ...
# Web Manager                   web-technologies (20%)
# Web Programmer                             php (29%)
# Web Specialist                       it-skills (22%)
# Web User Interface Developer            web-ui (35%)
# Webmaster                                 html (42%)
#
#                                                           1  \
# Application Developer                business-process (14%)
# Application Engineer                          jenkins (10%)
# Application Sales Specialist  application-development (16%)
# Area Manager                                marketing (12%)
# Area Sales Manager               business-development (27%)
# ...                                                     ...
# Web Manager                                 it-skills (20%)
# Web Programmer                             javascript (22%)
# Web Specialist                       web-technologies (15%)
# Web User Interface Developer               javascript (33%)
# Webmaster                            google-analytics (26%)
#
#                                                         2  \
# Application Developer                    javascript (12%)
# Application Engineer                           java (10%)
# Application Sales Specialist              it-skills (13%)
# Area Manager                        area-management (12%)
# Area Sales Manager            area-sales-management (22%)
# ...                                                   ...
# Web Manager                      project-management (12%)
# Web Programmer                                 html (22%)
# Web Specialist                         social-media (11%)
# Web User Interface Developer                    css (18%)
# Webmaster                                javascript (22%)
#
#                                                           3  \
# Application Developer                          oracle (12%)
# Application Engineer          configuration-management (8%)
# Application Sales Specialist          lead-generation (13%)
# Area Manager                     business-development (10%)
# Area Sales Manager                              sales (20%)
# ...                                                     ...
# Web Manager                                       seo (10%)
# Web Programmer                       web-technologies (20%)
# Web Specialist                                   none (11%)
# Web User Interface Developer                     html (16%)
# Webmaster                                         css (20%)
#
#                                                     4
# Application Developer             communication (12%)
# Application Engineer                         git (8%)
# Application Sales Specialist  digital-marketing (10%)
# Area Manager                  area-sales-manager (8%)
# Area Sales Manager                channel-sales (20%)
# ...                                               ...
# Web Manager                          javascript (10%)
# Web Programmer                            mysql (20%)
# Web Specialist                        javascript (8%)
# Web User Interface Developer            angular (11%)
# Webmaster                                   seo (20%)
#
# [402 rows x 5 columns]
